# %% [markdown]
# # Functions in pandas

# %% [markdown]
# Let's import a dataset using pandas function.
# The function read_csv reads the dataset from a csv file. There are also other functions for different file like read_excel.

# %%
import pandas as pd

# %%
data = pd.read_csv('Water_pond_tanks_2021.csv',encoding='cp1252')

# data = pd.to_csv("")

# %% [markdown]
# Pandas registers the data read from a dataset as a dataframe by default

# %%
data
# Out:
#      STN\nCode                        Name of Monitoring Location  \
# 0       4368.0      KOLLERU LAKE KOKKIRAYALANKA (V), KAILALUR (M)
# 1       2353.0  KONDAKARLA-AAVA LAKE, PARAWADA PHARMA CITY, VI...
# 2       1790.0                       PULICATE LAKE , NELLORE DIST
# 3       4391.0      CHENGAMBAKAM TANK IN SRI CITY SEZ,\nTIRUPATHI
# 4       4921.0           ANNAMAYYA PROJECT ON CHEYYERU\nRESERVOIR
# ..         ...                                                ...
# 615     1765.0  RABINDRASAROVAR NATIONAL LAKE,\nCALCUTTA, WEST...
# 616     2544.0                              SAHEBBANDH AT PURULIA
# 617     2522.0                        SINCHAL LAKE FOR DARJEELING
# 618     2521.0          WATER RESERVIOR AT DELO LAKE,\nDARJELLING
# 619     4725.0                  WATER RESERVIOR ST. HELENS SCHOOL
#
#     Type Water Body      State Name  Temperature\n?C (Min)  \
# 0              LAKE  ANDHRA PRADESH                   24.0
# 1              LAKE  ANDHRA PRADESH                   26.0
# 2              LAKE  ANDHRA PRADESH                   18.0
# 3              TANK  ANDHRA PRADESH                   22.0
# 4           Wetland  ANDHRA PRADESH                   21.0
# ..              ...             ...                    ...
# 615            LAKE     WEST BENGAL                   22.0
# 616            LAKE     WEST BENGAL                   22.0
# 617            LAKE     WEST BENGAL                    7.0
# 618            LAKE     WEST BENGAL                    9.0
# 619            LAKE     WEST BENGAL                    8.0
#
#      Temperature\n?C (Max) Dissolved Oxygen (mg/L) (Min)  \
# 0                     27.0                           3.2
# 1                     29.0                           3.0
# 2                     24.0                           4.2
# 3                     29.0                           5.4
# 4                     30.0                           5.4
# ..                     ...                           ...
# 615                   31.0                           5.2
# 616                   32.0                           8.8
# 617                   16.0                           7.1
# 618                   24.0                           7.2
# 619                   18.0                           7.1
#
#     Dissolved Oxygen (mg/L) (Max) pH (Min)  pH (Max)  \
# 0                             6.5      7.0       8.0
# 1                             6.8      6.9       7.8
# 2                             6.0      7.2       8.2
# 3                             6.2      6.3       7.9
# 4                             6.5      7.3       8.0
# ..                            ...      ...       ...
# 615                           9.7      7.2       8.5
# 616                           9.8      7.0       7.6
# 617                           8.1      6.9       7.6
# 618                           8.2      6.9       7.6
# 619                           8.5      6.9       7.9
#
#     Conductivity (?mhos/cm) (Min) Conductivity (?mhos/cm) (Max)  \
# 0                             245                          5160
# 1                             599                          1179
# 2                           28000                         56900
# 3                             180                           476
# 4                             496                           734
# ..                            ...                           ...
# 615                           252                           826
# 616                           311                           422
# 617                            13                            29
# 618                            20                            36
# 619                            16                            73
#
#     BOD (mg/L) (Min) BOD (mg/L) (Max) Nitrate N + Nitrite N(mg/L) (Min)  \
# 0                1.6              3.2                              1.02
# 1                1.9              4.6                              0.77
# 2                2.4              2.8                              1.20
# 3                1.0              2.5                              0.34
# 4                1.0              2.3                              0.35
# ..               ...              ...                               ...
# 615              1.8              4.1                              0.30
# 616              2.7              7.3                              0.30
# 617              1.0              1.1                              0.30
# 618              1.0              1.8                              0.30
# 619              1.0              1.6                              0.30
#
#     Nitrate N + Nitrite N(mg/L) (Max) Fecal Coliform (MPN/100ml) (Min)  \
# 0                                3.60                                9
# 1                                3.56                               15
# 2                                1.64                                3
# 3                                2.30                               24
# 4                                1.00                               43
# ..                                ...                              ...
# 615                              1.90                              330
# 616                              0.80                             3100
# 617                              0.30                               70
# 618                              0.30                               60
# 619                              0.30                               70
#
#     Fecal Coliform (MPN/100ml) (Max) Total Coliform (MPN/100ml) (Min)  \
# 0                                 21                              120
# 1                                 23                              150
# 2                                  3                               47
# 3                                365                              170
# 4                                289                              240
# ..                               ...                              ...
# 615                              790                             1100
# 616                             9400                             4300
# 617                              110                              110
# 618                              130                              110
# 619                              110                              110
#
#     Total Coliform (MPN/100ml) (Max)
# 0                                210
# 1                                240
# 2                                150
# 3                                549
# 4                                727
# ..                               ...
# 615                             1700
# 616                            12000
# 617                              210
# 618                              330
# 619                              330
#
# [620 rows x 20 columns]

# %% [markdown]
# The rows in the above dataframe are called samples(if it is a subset of a large dataset) or dataset instances(if you consider the whole population).
#
# **In machine learning terminology, the columns are called features of the dataset.**

# %%
#To get the features, i.e. columns in the dataset
data.columns
# Out:
# Index(['STN\nCode', 'Name of Monitoring Location', 'Type Water Body',
#        'State Name', 'Temperature\n?C (Min)', 'Temperature\n?C (Max)',
#        'Dissolved Oxygen (mg/L) (Min)', 'Dissolved Oxygen (mg/L) (Max)',
#        'pH (Min)', 'pH (Max)', 'Conductivity (?mhos/cm) (Min)',
#        'Conductivity (?mhos/cm) (Max)', 'BOD (mg/L) (Min)', 'BOD (mg/L) (Max)',
#        'Nitrate N + Nitrite N(mg/L) (Min)',
#        'Nitrate N + Nitrite N(mg/L) (Max)', 'Fecal Coliform (MPN/100ml) (Min)',
#        'Fecal Coliform (MPN/100ml) (Max)', 'Total Coliform (MPN/100ml) (Min)',
#        'Total Coliform (MPN/100ml) (Max)'],
#       dtype='object')

# %% [markdown]
# To rename the columns we can use rename function

# %%
data.rename(columns = {"Name of Monitoring Location": "Monitoring Location"},inplace=True)
data
# Out:
#      STN\nCode                                Monitoring Location  \
# 0       4368.0      KOLLERU LAKE KOKKIRAYALANKA (V), KAILALUR (M)
# 1       2353.0  KONDAKARLA-AAVA LAKE, PARAWADA PHARMA CITY, VI...
# 2       1790.0                       PULICATE LAKE , NELLORE DIST
# 3       4391.0      CHENGAMBAKAM TANK IN SRI CITY SEZ,\nTIRUPATHI
# 4       4921.0           ANNAMAYYA PROJECT ON CHEYYERU\nRESERVOIR
# ..         ...                                                ...
# 615     1765.0  RABINDRASAROVAR NATIONAL LAKE,\nCALCUTTA, WEST...
# 616     2544.0                              SAHEBBANDH AT PURULIA
# 617     2522.0                        SINCHAL LAKE FOR DARJEELING
# 618     2521.0          WATER RESERVIOR AT DELO LAKE,\nDARJELLING
# 619     4725.0                  WATER RESERVIOR ST. HELENS SCHOOL
#
#     Type Water Body      State Name  Temperature\n?C (Min)  \
# 0              LAKE  ANDHRA PRADESH                   24.0
# 1              LAKE  ANDHRA PRADESH                   26.0
# 2              LAKE  ANDHRA PRADESH                   18.0
# 3              TANK  ANDHRA PRADESH                   22.0
# 4           Wetland  ANDHRA PRADESH                   21.0
# ..              ...             ...                    ...
# 615            LAKE     WEST BENGAL                   22.0
# 616            LAKE     WEST BENGAL                   22.0
# 617            LAKE     WEST BENGAL                    7.0
# 618            LAKE     WEST BENGAL                    9.0
# 619            LAKE     WEST BENGAL                    8.0
#
#      Temperature\n?C (Max) Dissolved Oxygen (mg/L) (Min)  \
# 0                     27.0                           3.2
# 1                     29.0                           3.0
# 2                     24.0                           4.2
# 3                     29.0                           5.4
# 4                     30.0                           5.4
# ..                     ...                           ...
# 615                   31.0                           5.2
# 616                   32.0                           8.8
# 617                   16.0                           7.1
# 618                   24.0                           7.2
# 619                   18.0                           7.1
#
#     Dissolved Oxygen (mg/L) (Max) pH (Min)  pH (Max)  \
# 0                             6.5      7.0       8.0
# 1                             6.8      6.9       7.8
# 2                             6.0      7.2       8.2
# 3                             6.2      6.3       7.9
# 4                             6.5      7.3       8.0
# ..                            ...      ...       ...
# 615                           9.7      7.2       8.5
# 616                           9.8      7.0       7.6
# 617                           8.1      6.9       7.6
# 618                           8.2      6.9       7.6
# 619                           8.5      6.9       7.9
#
#     Conductivity (?mhos/cm) (Min) Conductivity (?mhos/cm) (Max)  \
# 0                             245                          5160
# 1                             599                          1179
# 2                           28000                         56900
# 3                             180                           476
# 4                             496                           734
# ..                            ...                           ...
# 615                           252                           826
# 616                           311                           422
# 617                            13                            29
# 618                            20                            36
# 619                            16                            73
#
#     BOD (mg/L) (Min) BOD (mg/L) (Max) Nitrate N + Nitrite N(mg/L) (Min)  \
# 0                1.6              3.2                              1.02
# 1                1.9              4.6                              0.77
# 2                2.4              2.8                              1.20
# 3                1.0              2.5                              0.34
# 4                1.0              2.3                              0.35
# ..               ...              ...                               ...
# 615              1.8              4.1                              0.30
# 616              2.7              7.3                              0.30
# 617              1.0              1.1                              0.30
# 618              1.0              1.8                              0.30
# 619              1.0              1.6                              0.30
#
#     Nitrate N + Nitrite N(mg/L) (Max) Fecal Coliform (MPN/100ml) (Min)  \
# 0                                3.60                                9
# 1                                3.56                               15
# 2                                1.64                                3
# 3                                2.30                               24
# 4                                1.00                               43
# ..                                ...                              ...
# 615                              1.90                              330
# 616                              0.80                             3100
# 617                              0.30                               70
# 618                              0.30                               60
# 619                              0.30                               70
#
#     Fecal Coliform (MPN/100ml) (Max) Total Coliform (MPN/100ml) (Min)  \
# 0                                 21                              120
# 1                                 23                              150
# 2                                  3                               47
# 3                                365                              170
# 4                                289                              240
# ..                               ...                              ...
# 615                              790                             1100
# 616                             9400                             4300
# 617                              110                              110
# 618                              130                              110
# 619                              110                              110
#
#     Total Coliform (MPN/100ml) (Max)
# 0                                210
# 1                                240
# 2                                150
# 3                                549
# 4                                727
# ..                               ...
# 615                             1700
# 616                            12000
# 617                              210
# 618                              330
# 619                              330
#
# [620 rows x 20 columns]

# %% [markdown]
# The functions head and tail give a peek of the dataset

# %%
data.head(10)
# Out:
#    STN\nCode                                Monitoring Location  \
# 0     4368.0      KOLLERU LAKE KOKKIRAYALANKA (V), KAILALUR (M)
# 1     2353.0  KONDAKARLA-AAVA LAKE, PARAWADA PHARMA CITY, VI...
# 2     1790.0                       PULICATE LAKE , NELLORE DIST
# 3     4391.0      CHENGAMBAKAM TANK IN SRI CITY SEZ,\nTIRUPATHI
# 4     4921.0           ANNAMAYYA PROJECT ON CHEYYERU\nRESERVOIR
# 5     4936.0                               ANUMANAPALLE CHERUVU
# 6     4919.0                                        BRAMHASAGAR
# 7     4926.0                                          DALI TANK
# 8     4931.0                         GACCHAKAYALA PORA (LAGOON)
# 9     4917.0                                  GANGINENI CHERUVU
#
#   Type Water Body      State Name  Temperature\n?C (Min)  \
# 0            LAKE  ANDHRA PRADESH                   24.0
# 1            LAKE  ANDHRA PRADESH                   26.0
# 2            LAKE  ANDHRA PRADESH                   18.0
# 3            TANK  ANDHRA PRADESH                   22.0
# 4         Wetland  ANDHRA PRADESH                   21.0
# 5         Wetland  ANDHRA PRADESH                   22.0
# 6         Wetland  ANDHRA PRADESH                   20.0
# 7         Wetland  ANDHRA PRADESH                   22.0
# 8         Wetland  ANDHRA PRADESH                   27.0
# 9         Wetland  ANDHRA PRADESH                   21.0
#
#    Temperature\n?C (Max) Dissolved Oxygen (mg/L) (Min)  \
# 0                   27.0                           3.2
# 1                   29.0                           3.0
# 2                   24.0                           4.2
# 3                   29.0                           5.4
# 4                   30.0                           5.4
# 5                   23.0                           6.8
# 6                   29.0                           5.1
# 7                   31.0                           4.2
# 8                   31.0                           4.5
# 9                   30.0                           3.8
#
#   Dissolved Oxygen (mg/L) (Max) pH (Min)  pH (Max)  \
# 0                           6.5      7.0       8.0
# 1                           6.8      6.9       7.8
# 2                           6.0      7.2       8.2
# 3                           6.2      6.3       7.9
# 4                           6.5      7.3       8.0
# 5                           7.5      7.1       9.0
# 6                           6.4      7.1       7.9
# 7                           7.3      7.1       8.5
# 8                           7.2      7.1       8.6
# 9                           5.8      6.6       8.1
#
#   Conductivity (?mhos/cm) (Min) Conductivity (?mhos/cm) (Max)  \
# 0                           245                          5160
# 1                           599                          1179
# 2                         28000                         56900
# 3                           180                           476
# 4                           496                           734
# 5                           158                           320
# 6                           381                           608
# 7                           274                         18950
# 8                         12230                         56900
# 9                           802                          1326
#
#   BOD (mg/L) (Min) BOD (mg/L) (Max) Nitrate N + Nitrite N(mg/L) (Min)  \
# 0              1.6              3.2                              1.02
# 1              1.9              4.6                              0.77
# 2              2.4              2.8                              1.20
# 3              1.0              2.5                              0.34
# 4              1.0              2.3                              0.35
# 5              1.2              2.2                              0.42
# 6              1.0              2.2                              0.32
# 7              1.5              2.5                              0.38
# 8              1.4              3.6                              0.63
# 9              2.2              3.5                              1.08
#
#   Nitrate N + Nitrite N(mg/L) (Max) Fecal Coliform (MPN/100ml) (Min)  \
# 0                              3.60                                9
# 1                              3.56                               15
# 2                              1.64                                3
# 3                              2.30                               24
# 4                              1.00                               43
# 5                              1.79                                3
# 6                              0.67                               45
# 7                              2.82                                4
# 8                              2.86                                4
# 9                              4.51                              191
#
#   Fecal Coliform (MPN/100ml) (Max) Total Coliform (MPN/100ml) (Min)  \
# 0                               21                              120
# 1                               23                              150
# 2                                3                               47
# 3                              365                              170
# 4                              289                              240
# 5                                4                               63
# 6                              322                              210
# 7                               15                                2
# 8                               15                               64
# 9                              659                              540
#
#   Total Coliform (MPN/100ml) (Max)
# 0                              210
# 1                              240
# 2                              150
# 3                              549
# 4                              727
# 5                              150
# 6                              602
# 7                              150
# 8                              120
# 9                             1120

# %%
data.tail(7)
# Out:
#      STN\nCode                                Monitoring Location  \
# 613     2504.0    MAINH GHAT ON DUDHPUKUR AT TARAKESHWAR, HOOGHLY
# 614     2520.0                            MIRIKH LAKE, DARJEELING
# 615     1765.0  RABINDRASAROVAR NATIONAL LAKE,\nCALCUTTA, WEST...
# 616     2544.0                              SAHEBBANDH AT PURULIA
# 617     2522.0                        SINCHAL LAKE FOR DARJEELING
# 618     2521.0          WATER RESERVIOR AT DELO LAKE,\nDARJELLING
# 619     4725.0                  WATER RESERVIOR ST. HELENS SCHOOL
#
#     Type Water Body   State Name  Temperature\n?C (Min)  \
# 613            LAKE  WEST BENGAL                   22.5
# 614            LAKE  WEST BENGAL                    4.0
# 615            LAKE  WEST BENGAL                   22.0
# 616            LAKE  WEST BENGAL                   22.0
# 617            LAKE  WEST BENGAL                    7.0
# 618            LAKE  WEST BENGAL                    9.0
# 619            LAKE  WEST BENGAL                    8.0
#
#      Temperature\n?C (Max) Dissolved Oxygen (mg/L) (Min)  \
# 613                   34.0                           3.8
# 614                   24.0                           5.8
# 615                   31.0                           5.2
# 616                   32.0                           8.8
# 617                   16.0                           7.1
# 618                   24.0                           7.2
# 619                   18.0                           7.1
#
#     Dissolved Oxygen (mg/L) (Max) pH (Min)  pH (Max)  \
# 613                          12.0      7.6       8.7
# 614                           6.9      6.5       8.0
# 615                           9.7      7.2       8.5
# 616                           9.8      7.0       7.6
# 617                           8.1      6.9       7.6
# 618                           8.2      6.9       7.6
# 619                           8.5      6.9       7.9
#
#     Conductivity (?mhos/cm) (Min) Conductivity (?mhos/cm) (Max)  \
# 613                           569                           775
# 614                            67                           196
# 615                           252                           826
# 616                           311                           422
# 617                            13                            29
# 618                            20                            36
# 619                            16                            73
#
#     BOD (mg/L) (Min) BOD (mg/L) (Max) Nitrate N + Nitrite N(mg/L) (Min)  \
# 613              3.6              7.2                              0.30
# 614              1.8              2.8                              0.30
# 615              1.8              4.1                              0.30
# 616              2.7              7.3                              0.30
# 617              1.0              1.1                              0.30
# 618              1.0              1.8                              0.30
# 619              1.0              1.6                              0.30
#
#     Nitrate N + Nitrite N(mg/L) (Max) Fecal Coliform (MPN/100ml) (Min)  \
# 613                              0.90                            13000
# 614                              0.32                             2100
# 615                              1.90                              330
# 616                              0.80                             3100
# 617                              0.30                               70
# 618                              0.30                               60
# 619                              0.30                               70
#
#     Fecal Coliform (MPN/100ml) (Max) Total Coliform (MPN/100ml) (Min)  \
# 613                           240000                            23000
# 614                             5000                             5000
# 615                              790                             1100
# 616                             9400                             4300
# 617                              110                              110
# 618                              130                              110
# 619                              110                              110
#
#     Total Coliform (MPN/100ml) (Max)
# 613                           540000
# 614                            14000
# 615                             1700
# 616                            12000
# 617                              210
# 618                              330
# 619                              330

# %% [markdown]
# The shape function provides information about the dimensions of the dataset

# %%
data.shape
# Out:
# (620, 20)

# %% [markdown]
# The info function provides you with the general structure of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   STN
# Code                           619 non-null    float64
#  1   Monitoring Location                620 non-null    object
#  2   Type Water Body                    620 non-null    object
#  3   State Name                         620 non-null    object
#  4   Temperature
# ?C (Min)               617 non-null    float64
#  5   Temperature
# ?C (Max)               617 non-null    float64
#  6   Dissolved Oxygen (mg/L) (Min)      620 non-null    object
#  7   Dissolved Oxygen (mg/L) (Max)      620 non-null    object
#  8   pH (Min)                           620 non-null    object
#  9   pH (Max)                           620 non-null    float64
#  10  Conductivity (?mhos/cm) (Min)      618 non-null    object
#  11  Conductivity (?mhos/cm) (Max)      618 non-null    object
#  12  BOD (mg/L) (Min)                   620 non-null    object
#  13  BOD (mg/L) (Max)                   620 non-null    object
#  14  Nitrate N + Nitrite N(mg/L) (Min)  620 non-null    object
#  15  Nitrate N + Nitrite N(mg/L) (Max)  620 non-null    object
#  16  Fecal Coliform (MPN/100ml) (Min)   619 non-null    object
#  17  Fecal Coliform (MPN/100ml) (Max)   619 non-null    object
#  18  Total Coliform (MPN/100ml) (Min)   619 non-null    object
#  19  Total Coliform (MPN/100ml) (Max)   619 non-null    object
# dtypes: float64(4), object(16)
# memory usage: 97.0+ KB

# %% [markdown]
# The function isna returns boolean value for each datapoint in the dataset i.e. either true or false by checking whether a number is NaN or not
#
# NaN , standing for not a number, is a numeric data type used to represent any value that is undefined or unpresentable. For example, 0/0 is undefined as a real number and is, therefore, represented by NaN.

# %%
data.isna()
# Out:
#      STN\nCode  Monitoring Location  Type Water Body  State Name  \
# 0        False                False            False       False
# 1        False                False            False       False
# 2        False                False            False       False
# 3        False                False            False       False
# 4        False                False            False       False
# ..         ...                  ...              ...         ...
# 615      False                False            False       False
# 616      False                False            False       False
# 617      False                False            False       False
# 618      False                False            False       False
# 619      False                False            False       False
#
#      Temperature\n?C (Min)  Temperature\n?C (Max)  \
# 0                    False                  False
# 1                    False                  False
# 2                    False                  False
# 3                    False                  False
# 4                    False                  False
# ..                     ...                    ...
# 615                  False                  False
# 616                  False                  False
# 617                  False                  False
# 618                  False                  False
# 619                  False                  False
#
#      Dissolved Oxygen (mg/L) (Min)  Dissolved Oxygen (mg/L) (Max)  pH (Min)  \
# 0                            False                          False     False
# 1                            False                          False     False
# 2                            False                          False     False
# 3                            False                          False     False
# 4                            False                          False     False
# ..                             ...                            ...       ...
# 615                          False                          False     False
# 616                          False                          False     False
# 617                          False                          False     False
# 618                          False                          False     False
# 619                          False                          False     False
#
#      pH (Max)  Conductivity (?mhos/cm) (Min)  Conductivity (?mhos/cm) (Max)  \
# 0       False                          False                          False
# 1       False                          False                          False
# 2       False                          False                          False
# 3       False                          False                          False
# 4       False                          False                          False
# ..        ...                            ...                            ...
# 615     False                          False                          False
# 616     False                          False                          False
# 617     False                          False                          False
# 618     False                          False                          False
# 619     False                          False                          False
#
#      BOD (mg/L) (Min)  BOD (mg/L) (Max)  Nitrate N + Nitrite N(mg/L) (Min)  \
# 0               False             False                              False
# 1               False             False                              False
# 2               False             False                              False
# 3               False             False                              False
# 4               False             False                              False
# ..                ...               ...                                ...
# 615             False             False                              False
# 616             False             False                              False
# 617             False             False                              False
# 618             False             False                              False
# 619             False             False                              False
#
#      Nitrate N + Nitrite N(mg/L) (Max)  Fecal Coliform (MPN/100ml) (Min)  \
# 0                                False                             False
# 1                                False                             False
# 2                                False                             False
# 3                                False                             False
# 4                                False                             False
# ..                                 ...                               ...
# 615                              False                             False
# 616                              False                             False
# 617                              False                             False
# 618                              False                             False
# 619                              False                             False
#
#      Fecal Coliform (MPN/100ml) (Max)  Total Coliform (MPN/100ml) (Min)  \
# 0                               False                             False
# 1                               False                             False
# 2                               False                             False
# 3                               False                             False
# 4                               False                             False
# ..                                ...                               ...
# 615                             False                             False
# 616                             False                             False
# 617                             False                             False
# 618                             False                             False
# 619                             False                             False
#
#      Total Coliform (MPN/100ml) (Max)
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# ..                                ...
# 615                             False
# 616                             False
# 617                             False
# 618                             False
# 619                             False
#
# [620 rows x 20 columns]

# %% [markdown]
# The describe function provides you with the information about the statistics of variables like count, mean, standard deviation, etc
#
# The 25%, 50%, 75% values are called quartiles of a dataset. Quartiles are the set of values which has three points dividing the data set into four identical parts.

# %%
data.describe()
# Out:
#          STN\nCode  Temperature\n?C (Min)  Temperature\n?C (Max)    pH (Max)
# count   619.000000             617.000000             617.000000  620.000000
# mean   3442.067851              21.805186              28.374716    8.029194
# std    1065.368325               4.657455               3.647189    0.492039
# min    1263.000000               4.000000              16.000000    6.700000
# 25%    2530.500000              20.000000              25.000000    7.600000
# 50%    3619.000000              22.000000              28.000000    8.000000
# 75%    4352.500000              25.000000              30.300000    8.400000
# max    5063.000000              34.000000              42.000000   10.300000

# %% [markdown]
# The function nunique provides total number of unique values in each column of the dataframe

# %%
data.nunique()
#Eg State name tells us there are 32 unique values of states i.e., we have 32 states under consideration
# Out:
# STN\nCode                            619
# Monitoring Location                  615
# Type Water Body                        4
# State Name                            32
# Temperature\n?C (Min)                 59
# Temperature\n?C (Max)                 53
# Dissolved Oxygen (mg/L) (Min)         79
# Dissolved Oxygen (mg/L) (Max)        107
# pH (Min)                              31
# pH (Max)                              30
# Conductivity (?mhos/cm) (Min)        443
# Conductivity (?mhos/cm) (Max)        509
# BOD (mg/L) (Min)                      63
# BOD (mg/L) (Max)                     135
# Nitrate N + Nitrite N(mg/L) (Min)    147
# Nitrate N + Nitrite N(mg/L) (Max)    287
# Fecal Coliform (MPN/100ml) (Min)     115
# Fecal Coliform (MPN/100ml) (Max)     186
# Total Coliform (MPN/100ml) (Min)     137
# Total Coliform (MPN/100ml) (Max)     149
# dtype: int64

# %% [markdown]
# The function unique provides with all the unique values for a particular column in the dataframe

# %%
data['Type Water Body'].unique()
# Out:
# array(['LAKE', 'TANK', 'Wetland', 'POND'], dtype=object)

# %% [markdown]
# The value_counts functions will return the count for each unique value present in the dataset

# %%
data['Monitoring Location'].value_counts()
# Out:
# GOTTIGERE LAKE                       2
# PEDDA CHERUVU                        2
# MANCHANABALE DAM                     2
# HEBBAL LAKE                          2
# RAMAMMANA KERE                       2
#                                     ..
# PARAPPANA AGRAHARA LAKE              1
# PATTANDUR AGARAHARA                  1
# PUTTENAHALLI LAKE                    1
# PUTTENAHALLI LAKE (S)                1
# WATER RESERVIOR ST. HELENS SCHOOL    1
# Name: Monitoring Location, Length: 615, dtype: int64

# %% [markdown]
# The drop function can be used to drop the column.

# %%
data = data.drop(['Monitoring Location'], axis=1)
data.head()
# Out:
#    STN\nCode Type Water Body      State Name  Temperature\n?C (Min)  \
# 0     4368.0            LAKE  ANDHRA PRADESH                   24.0
# 1     2353.0            LAKE  ANDHRA PRADESH                   26.0
# 2     1790.0            LAKE  ANDHRA PRADESH                   18.0
# 3     4391.0            TANK  ANDHRA PRADESH                   22.0
# 4     4921.0         Wetland  ANDHRA PRADESH                   21.0
#
#    Temperature\n?C (Max) Dissolved Oxygen (mg/L) (Min)  \
# 0                   27.0                           3.2
# 1                   29.0                           3.0
# 2                   24.0                           4.2
# 3                   29.0                           5.4
# 4                   30.0                           5.4
#
#   Dissolved Oxygen (mg/L) (Max) pH (Min)  pH (Max)  \
# 0                           6.5      7.0       8.0
# 1                           6.8      6.9       7.8
# 2                           6.0      7.2       8.2
# 3                           6.2      6.3       7.9
# 4                           6.5      7.3       8.0
#
#   Conductivity (?mhos/cm) (Min) Conductivity (?mhos/cm) (Max)  \
# 0                           245                          5160
# 1                           599                          1179
# 2                         28000                         56900
# 3                           180                           476
# 4                           496                           734
#
#   BOD (mg/L) (Min) BOD (mg/L) (Max) Nitrate N + Nitrite N(mg/L) (Min)  \
# 0              1.6              3.2                              1.02
# 1              1.9              4.6                              0.77
# 2              2.4              2.8                              1.20
# 3              1.0              2.5                              0.34
# 4              1.0              2.3                              0.35
#
#   Nitrate N + Nitrite N(mg/L) (Max) Fecal Coliform (MPN/100ml) (Min)  \
# 0                              3.60                                9
# 1                              3.56                               15
# 2                              1.64                                3
# 3                              2.30                               24
# 4                              1.00                               43
#
#   Fecal Coliform (MPN/100ml) (Max) Total Coliform (MPN/100ml) (Min)  \
# 0                               21                              120
# 1                               23                              150
# 2                                3                               47
# 3                              365                              170
# 4                              289                              240
#
#   Total Coliform (MPN/100ml) (Max)
# 0                              210
# 1                              240
# 2                              150
# 3                              549
# 4                              727

# %% [markdown]
# The function iloc takes as a parameter the rows and column indices and gives you the subset of the DataFrame accordingly

# %%
data.iloc[:10,1:4]
# Out:
#   Type Water Body      State Name  Temperature\n?C (Min)
# 0            LAKE  ANDHRA PRADESH                   24.0
# 1            LAKE  ANDHRA PRADESH                   26.0
# 2            LAKE  ANDHRA PRADESH                   18.0
# 3            TANK  ANDHRA PRADESH                   22.0
# 4         Wetland  ANDHRA PRADESH                   21.0
# 5         Wetland  ANDHRA PRADESH                   22.0
# 6         Wetland  ANDHRA PRADESH                   20.0
# 7         Wetland  ANDHRA PRADESH                   22.0
# 8         Wetland  ANDHRA PRADESH                   27.0
# 9         Wetland  ANDHRA PRADESH                   21.0

# %% [markdown]
# The function loc() does almost the similar operation as iloc() function, but here we can specify exactly which row index we want and also the name of the columns we want in our subset

# %%
data.loc[[200],['Type Water Body','State Name']]
# Out:
#     Type Water Body State Name
# 200            LAKE  KARNATAKA

# %% [markdown]
# The dtypes tells us about the datatype that each column has

# %%
data.dtypes
# Out:
# STN\nCode                            float64
# Type Water Body                       object
# State Name                            object
# Temperature\n?C (Min)                float64
# Temperature\n?C (Max)                float64
# Dissolved Oxygen (mg/L) (Min)         object
# Dissolved Oxygen (mg/L) (Max)         object
# pH (Min)                              object
# pH (Max)                             float64
# Conductivity (?mhos/cm) (Min)         object
# Conductivity (?mhos/cm) (Max)         object
# BOD (mg/L) (Min)                      object
# BOD (mg/L) (Max)                      object
# Nitrate N + Nitrite N(mg/L) (Min)     object
# Nitrate N + Nitrite N(mg/L) (Max)     object
# Fecal Coliform (MPN/100ml) (Min)      object
# Fecal Coliform (MPN/100ml) (Max)      object
# Total Coliform (MPN/100ml) (Min)      object
# Total Coliform (MPN/100ml) (Max)      object
# dtype: object

# %% [markdown]
# The insert function to insert a random column

# %%
import numpy as np
random_col = np.random.randint(100, size=len(data))

data.insert(2, 'random_col', random_col)
data
# Out:
#      STN\nCode Type Water Body  random_col      State Name  \
# 0       4368.0            LAKE          55  ANDHRA PRADESH
# 1       2353.0            LAKE          49  ANDHRA PRADESH
# 2       1790.0            LAKE          85  ANDHRA PRADESH
# 3       4391.0            TANK          55  ANDHRA PRADESH
# 4       4921.0         Wetland          27  ANDHRA PRADESH
# ..         ...             ...         ...             ...
# 615     1765.0            LAKE          63     WEST BENGAL
# 616     2544.0            LAKE          63     WEST BENGAL
# 617     2522.0            LAKE          88     WEST BENGAL
# 618     2521.0            LAKE          62     WEST BENGAL
# 619     4725.0            LAKE          42     WEST BENGAL
#
#      Temperature\n?C (Min)  Temperature\n?C (Max)  \
# 0                     24.0                   27.0
# 1                     26.0                   29.0
# 2                     18.0                   24.0
# 3                     22.0                   29.0
# 4                     21.0                   30.0
# ..                     ...                    ...
# 615                   22.0                   31.0
# 616                   22.0                   32.0
# 617                    7.0                   16.0
# 618                    9.0                   24.0
# 619                    8.0                   18.0
#
#     Dissolved Oxygen (mg/L) (Min) Dissolved Oxygen (mg/L) (Max) pH (Min)  \
# 0                             3.2                           6.5      7.0
# 1                             3.0                           6.8      6.9
# 2                             4.2                           6.0      7.2
# 3                             5.4                           6.2      6.3
# 4                             5.4                           6.5      7.3
# ..                            ...                           ...      ...
# 615                           5.2                           9.7      7.2
# 616                           8.8                           9.8      7.0
# 617                           7.1                           8.1      6.9
# 618                           7.2                           8.2      6.9
# 619                           7.1                           8.5      6.9
#
#      pH (Max) Conductivity (?mhos/cm) (Min) Conductivity (?mhos/cm) (Max)  \
# 0         8.0                           245                          5160
# 1         7.8                           599                          1179
# 2         8.2                         28000                         56900
# 3         7.9                           180                           476
# 4         8.0                           496                           734
# ..        ...                           ...                           ...
# 615       8.5                           252                           826
# 616       7.6                           311                           422
# 617       7.6                            13                            29
# 618       7.6                            20                            36
# 619       7.9                            16                            73
#
#     BOD (mg/L) (Min) BOD (mg/L) (Max) Nitrate N + Nitrite N(mg/L) (Min)  \
# 0                1.6              3.2                              1.02
# 1                1.9              4.6                              0.77
# 2                2.4              2.8                              1.20
# 3                1.0              2.5                              0.34
# 4                1.0              2.3                              0.35
# ..               ...              ...                               ...
# 615              1.8              4.1                              0.30
# 616              2.7              7.3                              0.30
# 617              1.0              1.1                              0.30
# 618              1.0              1.8                              0.30
# 619              1.0              1.6                              0.30
#
#     Nitrate N + Nitrite N(mg/L) (Max) Fecal Coliform (MPN/100ml) (Min)  \
# 0                                3.60                                9
# 1                                3.56                               15
# 2                                1.64                                3
# 3                                2.30                               24
# 4                                1.00                               43
# ..                                ...                              ...
# 615                              1.90                              330
# 616                              0.80                             3100
# 617                              0.30                               70
# 618                              0.30                               60
# 619                              0.30                               70
#
#     Fecal Coliform (MPN/100ml) (Max) Total Coliform (MPN/100ml) (Min)  \
# 0                                 21                              120
# 1                                 23                              150
# 2                                  3                               47
# 3                                365                              170
# 4                                289                              240
# ..                               ...                              ...
# 615                              790                             1100
# 616                             9400                             4300
# 617                              110                              110
# 618                              130                              110
# 619                              110                              110
#
#     Total Coliform (MPN/100ml) (Max)
# 0                                210
# 1                                240
# 2                                150
# 3                                549
# 4                                727
# ..                               ...
# 615                             1700
# 616                            12000
# 617                              210
# 618                              330
# 619                              330
#
# [620 rows x 20 columns]

# %%
data.head()
# Out:
#    STN\nCode Type Water Body  random_col      State Name  \
# 0     4368.0            LAKE          55  ANDHRA PRADESH
# 1     2353.0            LAKE          49  ANDHRA PRADESH
# 2     1790.0            LAKE          85  ANDHRA PRADESH
# 3     4391.0            TANK          55  ANDHRA PRADESH
# 4     4921.0         Wetland          27  ANDHRA PRADESH
#
#    Temperature\n?C (Min)  Temperature\n?C (Max) Dissolved Oxygen (mg/L) (Min)  \
# 0                   24.0                   27.0                           3.2
# 1                   26.0                   29.0                           3.0
# 2                   18.0                   24.0                           4.2
# 3                   22.0                   29.0                           5.4
# 4                   21.0                   30.0                           5.4
#
#   Dissolved Oxygen (mg/L) (Max) pH (Min)  pH (Max)  \
# 0                           6.5      7.0       8.0
# 1                           6.8      6.9       7.8
# 2                           6.0      7.2       8.2
# 3                           6.2      6.3       7.9
# 4                           6.5      7.3       8.0
#
#   Conductivity (?mhos/cm) (Min) Conductivity (?mhos/cm) (Max)  \
# 0                           245                          5160
# 1                           599                          1179
# 2                         28000                         56900
# 3                           180                           476
# 4                           496                           734
#
#   BOD (mg/L) (Min) BOD (mg/L) (Max) Nitrate N + Nitrite N(mg/L) (Min)  \
# 0              1.6              3.2                              1.02
# 1              1.9              4.6                              0.77
# 2              2.4              2.8                              1.20
# 3              1.0              2.5                              0.34
# 4              1.0              2.3                              0.35
#
#   Nitrate N + Nitrite N(mg/L) (Max) Fecal Coliform (MPN/100ml) (Min)  \
# 0                              3.60                                9
# 1                              3.56                               15
# 2                              1.64                                3
# 3                              2.30                               24
# 4                              1.00                               43
#
#   Fecal Coliform (MPN/100ml) (Max) Total Coliform (MPN/100ml) (Min)  \
# 0                               21                              120
# 1                               23                              150
# 2                                3                               47
# 3                              365                              170
# 4                              289                              240
#
#   Total Coliform (MPN/100ml) (Max)
# 0                              210
# 1                              240
# 2                              150
# 3                              549
# 4                              727

# %% [markdown]
# The sample function will randomly sample 100 datapoints from the dataset

# %%
data.sample(100)
# Out:
#      STN\nCode Type Water Body  random_col   State Name  \
# 50      1263.0            POND          45        ASSAM
# 281     3599.0            TANK          31    KARNATAKA
# 189     3611.0            LAKE          59    KARNATAKA
# 30      1529.0            LAKE          33        ASSAM
# 271     3588.0            TANK          77    KARNATAKA
# ..         ...             ...         ...          ...
# 561     2348.0            TANK          92    TELANGANA
# 177     3654.0            LAKE          29    KARNATAKA
# 605     3437.0            LAKE          79  UTTARAKHAND
# 59      4006.0            POND          42        ASSAM
# 298     3565.0            TANK          45    KARNATAKA
#
#      Temperature\n?C (Min)  Temperature\n?C (Max)  \
# 50                    19.0                   29.0
# 281                   25.0                   25.0
# 189                   25.0                   25.0
# 30                    20.0                   31.0
# 271                   19.0                   26.0
# ..                     ...                    ...
# 561                   20.0                   25.0
# 177                   25.0                   26.0
# 605                   11.0                   23.0
# 59                    18.0                   35.0
# 298                   28.0                   30.0
#
#     Dissolved Oxygen (mg/L) (Min) Dissolved Oxygen (mg/L) (Max) pH (Min)  \
# 50                            4.0                           6.8      7.0
# 281                           3.4                           6.6      6.2
# 189                           0.3                           7.2      6.6
# 30                            4.2                          10.8      7.2
# 271                           6.0                           7.4      7.4
# ..                            ...                           ...      ...
# 561                           4.0                           5.6      7.0
# 177                           2.1                           6.8      6.1
# 605                           7.4                           9.0      7.2
# 59                            5.0                           7.6      6.0
# 298                           4.9                           7.9      6.5
#
#      pH (Max) Conductivity (?mhos/cm) (Min) Conductivity (?mhos/cm) (Max)  \
# 50        7.6                           206                           882
# 281       7.6                           213                          1240
# 189       7.7                           629                          1449
# 30        7.8                           150                           291
# 271       8.6                           496                           764
# ..        ...                           ...                           ...
# 561       7.3                          1428                          3964
# 177       7.1                           240                          2720
# 605       8.0                           160                           210
# 59        7.9                            64                            88
# 298       7.2                           128                           224
#
#     BOD (mg/L) (Min) BOD (mg/L) (Max) Nitrate N + Nitrite N(mg/L) (Min)  \
# 50               2.2              2.8                              0.80
# 281              2.0             13.0                              0.56
# 189              3.0             27.0                              0.93
# 30               2.2              5.2                              0.80
# 271              2.5              6.0                              1.50
# ..               ...              ...                               ...
# 561              5.0             10.0                             12.20
# 177              3.0             34.0                              0.30
# 605              1.0              1.6                              0.32
# 59               1.8              2.6                              0.70
# 298              2.0              3.0                              2.10
#
#     Nitrate N + Nitrite N(mg/L) (Max) Fecal Coliform (MPN/100ml) (Min)  \
# 50                               1.30                              300
# 281                              3.80                             2300
# 189                              6.00                             2200
# 30                               1.80                              300
# 271                              3.20                              700
# ..                                ...                              ...
# 561                             21.15                                2
# 177                              8.80                             4000
# 605                              0.37                               70
# 59                               1.10                              300
# 298                              7.00                               23
#
#     Fecal Coliform (MPN/100ml) (Max) Total Coliform (MPN/100ml) (Min)  \
# 50                               910                              730
# 281                           460000                            24000
# 189                          1700000                            24000
# 30                               730                              910
# 271                             1100                             4300
# ..                               ...                              ...
# 561                                8                               39
# 177                           120000                            24000
# 605                              170                              210
# 59                               360                              360
# 298                             1600                               23
#
#     Total Coliform (MPN/100ml) (Max)
# 50                              2100
# 281                          3500000
# 189                         16000000
# 30                              1600
# 271                             5800
# ..                               ...
# 561                               63
# 177                           920000
# 605                              540
# 59                               910
# 298                             1600
#
# [100 rows x 20 columns]

# %% [markdown]
# The replace function is used to replace all occurences of the given value with the new value.

# %%
data.replace({21.0 : 20.0})
data.head()
#data.replace({1.260 : 1.120, 5.555 : 0.435, 1.724 : 2.675})
# Out:
#    STN\nCode Type Water Body  random_col      State Name  \
# 0     4368.0            LAKE          55  ANDHRA PRADESH
# 1     2353.0            LAKE          49  ANDHRA PRADESH
# 2     1790.0            LAKE          85  ANDHRA PRADESH
# 3     4391.0            TANK          55  ANDHRA PRADESH
# 4     4921.0         Wetland          27  ANDHRA PRADESH
#
#    Temperature\n?C (Min)  Temperature\n?C (Max) Dissolved Oxygen (mg/L) (Min)  \
# 0                   24.0                   27.0                           3.2
# 1                   26.0                   29.0                           3.0
# 2                   18.0                   24.0                           4.2
# 3                   22.0                   29.0                           5.4
# 4                   21.0                   30.0                           5.4
#
#   Dissolved Oxygen (mg/L) (Max) pH (Min)  pH (Max)  \
# 0                           6.5      7.0       8.0
# 1                           6.8      6.9       7.8
# 2                           6.0      7.2       8.2
# 3                           6.2      6.3       7.9
# 4                           6.5      7.3       8.0
#
#   Conductivity (?mhos/cm) (Min) Conductivity (?mhos/cm) (Max)  \
# 0                           245                          5160
# 1                           599                          1179
# 2                         28000                         56900
# 3                           180                           476
# 4                           496                           734
#
#   BOD (mg/L) (Min) BOD (mg/L) (Max) Nitrate N + Nitrite N(mg/L) (Min)  \
# 0              1.6              3.2                              1.02
# 1              1.9              4.6                              0.77
# 2              2.4              2.8                              1.20
# 3              1.0              2.5                              0.34
# 4              1.0              2.3                              0.35
#
#   Nitrate N + Nitrite N(mg/L) (Max) Fecal Coliform (MPN/100ml) (Min)  \
# 0                              3.60                                9
# 1                              3.56                               15
# 2                              1.64                                3
# 3                              2.30                               24
# 4                              1.00                               43
#
#   Fecal Coliform (MPN/100ml) (Max) Total Coliform (MPN/100ml) (Min)  \
# 0                               21                              120
# 1                               23                              150
# 2                                3                               47
# 3                              365                              170
# 4                              289                              240
#
#   Total Coliform (MPN/100ml) (Max)
# 0                              210
# 1                              240
# 2                              150
# 3                              549
# 4                              727

# %% [markdown]
# Changing Datatype of a column

# %%
data['random_col'] = data['random_col'].astype(float)
print(data.dtypes)
# Out:
# STN\nCode                            float64
# Type Water Body                       object
# random_col                           float64
# State Name                            object
# Temperature\n?C (Min)                float64
# Temperature\n?C (Max)                float64
# Dissolved Oxygen (mg/L) (Min)         object
# Dissolved Oxygen (mg/L) (Max)         object
# pH (Min)                              object
# pH (Max)                             float64
# Conductivity (?mhos/cm) (Min)         object
# Conductivity (?mhos/cm) (Max)         object
# BOD (mg/L) (Min)                      object
# BOD (mg/L) (Max)                      object
# Nitrate N + Nitrite N(mg/L) (Min)     object
# Nitrate N + Nitrite N(mg/L) (Max)     object
# Fecal Coliform (MPN/100ml) (Min)      object
# Fecal Coliform (MPN/100ml) (Max)      object
# Total Coliform (MPN/100ml) (Min)      object
# Total Coliform (MPN/100ml) (Max)      object
# dtype: object
